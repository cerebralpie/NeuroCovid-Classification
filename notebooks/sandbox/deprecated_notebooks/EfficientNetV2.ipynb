# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import (
    Conv2D, Activation, BatchNormalization,
    UpSampling2D, Input, Concatenate
)
from tensorflow.keras.layers import Dropout, Conv2DTranspose, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetV2L
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K

# %%
tf.keras.backend.clear_session()
tf.config.set_visible_devices([], 'GPU')

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Hyperparameters

# %%
IMAGE_SIZE = 256
EPOCHS = 10
BATCH_SIZE = 4
LR = 1e-4

PATH = "."

# %% [markdown]
# # Dataset

# %%
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))
    
    total_size = len(images)
    valid_size = int(total_size * split)
    test_size = int(total_size * split)
    
    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)
    
    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)
    
    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x / 255.0
    
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    
    return x

# %% [markdown]
# ## Building the tf.data pipeline

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        
        return x, y
    
    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    
    return x, y


def tf_dataset(x, y, batch=BATCH_SIZE):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    
    return dataset

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    
    return x

# %% [markdown]
# # Model

# %%
#inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
#encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)

# %%
#encoder.summary()

# %%
inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
encoder2 = EfficientNetV2L(input_tensor=inputs, weights='imagenet', include_top=False)

# %%
len(encoder2.layers)
# Out:
# 1028

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")

    encoder = EfficientNetV2L(input_tensor=inputs, weights="imagenet", include_top=False)
    # skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    skip_connection_names = ["input_image", "block1d_project_activation", "block2g_expand_activation", "block4a_expand_activation", "block6a_expand_activation"]
    encoder_output = encoder.get_layer("top_activation").output
    #skip_connection_names = ["input_image", "re_lu", "re_lu_3", "re_lu_7"]
    #encoder_output = encoder.get_layer("re_lu_16").output

    f = [16, 32, 48, 64, 80]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])

        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)

    model = Model(inputs, x)
    return model

# %%
model = model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 256, 256, 3)          0         ['input_image[0][0]']
#
#  stem_conv (Conv2D)          (None, 128, 128, 32)         864       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 128, 128, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 128, 128, 32)         9216      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 128, 128, 32)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 128, 128, 32)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 128, 128, 32)         9216      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 128, 128, 32)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 128, 128, 32)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 128, 128, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block1c_project_conv (Conv  (None, 128, 128, 32)         9216      ['block1b_add[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_project_activation  (None, 128, 128, 32)         0         ['block1c_project_bn[0][0]']
#   (Activation)
#
#  block1c_drop (Dropout)      (None, 128, 128, 32)         0         ['block1c_project_activation[0
#                                                                     ][0]']
#
#  block1c_add (Add)           (None, 128, 128, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_project_conv (Conv  (None, 128, 128, 32)         9216      ['block1c_add[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_project_activation  (None, 128, 128, 32)         0         ['block1d_project_bn[0][0]']
#   (Activation)
#
#  block1d_drop (Dropout)      (None, 128, 128, 32)         0         ['block1d_project_activation[0
#                                                                     ][0]']
#
#  block1d_add (Add)           (None, 128, 128, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 128)          36864     ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 128)          512       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 128)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 64, 64, 64)           8192      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 64, 64, 256)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 64, 64, 64)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 64, 64, 64)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 64, 64, 256)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 64, 64, 64)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 64, 64, 64)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 64, 64, 256)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 64, 64, 64)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 64, 64, 64)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 64, 64, 256)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2e_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 64, 64, 64)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 64, 64, 64)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 64, 64, 256)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2f_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 64, 64, 64)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 64, 64, 64)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 64, 64, 256)          147456    ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 64, 64, 256)          1024      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 64, 64, 256)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_project_conv (Conv  (None, 64, 64, 64)           16384     ['block2g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2g_project_bn (BatchN  (None, 64, 64, 64)           256       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 64, 64, 64)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 64, 64, 64)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 256)          147456    ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 256)          1024      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 256)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 32, 32, 96)           24576     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 32, 32, 384)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 32, 32, 96)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 32, 32, 96)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 32, 32, 384)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 32, 32, 96)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 32, 32, 96)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 32, 32, 384)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 32, 32, 96)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 32, 32, 96)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3d_add[0][0]']
#  D)
#
#  block3e_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3e_expand_conv[0][0]']
#  rmalization)
#
#  block3e_expand_activation   (None, 32, 32, 384)          0         ['block3e_expand_bn[0][0]']
#  (Activation)
#
#  block3e_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3e_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3e_project_conv[0][0]']
#  ormalization)
#
#  block3e_drop (Dropout)      (None, 32, 32, 96)           0         ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)           (None, 32, 32, 96)           0         ['block3e_drop[0][0]',
#                                                                      'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3e_add[0][0]']
#  D)
#
#  block3f_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3f_expand_conv[0][0]']
#  rmalization)
#
#  block3f_expand_activation   (None, 32, 32, 384)          0         ['block3f_expand_bn[0][0]']
#  (Activation)
#
#  block3f_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3f_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3f_project_conv[0][0]']
#  ormalization)
#
#  block3f_drop (Dropout)      (None, 32, 32, 96)           0         ['block3f_project_bn[0][0]']
#
#  block3f_add (Add)           (None, 32, 32, 96)           0         ['block3f_drop[0][0]',
#                                                                      'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2  (None, 32, 32, 384)          331776    ['block3f_add[0][0]']
#  D)
#
#  block3g_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block3g_expand_conv[0][0]']
#  rmalization)
#
#  block3g_expand_activation   (None, 32, 32, 384)          0         ['block3g_expand_bn[0][0]']
#  (Activation)
#
#  block3g_project_conv (Conv  (None, 32, 32, 96)           36864     ['block3g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3g_project_bn (BatchN  (None, 32, 32, 96)           384       ['block3g_project_conv[0][0]']
#  ormalization)
#
#  block3g_drop (Dropout)      (None, 32, 32, 96)           0         ['block3g_project_bn[0][0]']
#
#  block3g_add (Add)           (None, 32, 32, 96)           0         ['block3g_drop[0][0]',
#                                                                      'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 32, 32, 384)          36864     ['block3g_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 32, 32, 384)          1536      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 32, 32, 384)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 16, 16, 384)          3456      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 16, 16, 384)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 384)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 16, 16, 384)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 16, 16, 192)          73728     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 16, 16, 192)          768       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 16, 16, 768)          147456    ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 16, 16, 768)          3072      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 16, 16, 768)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 16, 16, 768)          6912      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 16, 16, 768)          3072      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 16, 16, 768)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 768)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 16, 16, 768)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 16, 16, 192)          147456    ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 16, 16, 192)          768       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 16, 16, 192)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 16, 16, 192)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 16, 16, 768)          147456    ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 16, 16, 768)          3072      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 16, 16, 768)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 16, 16, 768)          6912      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 16, 16, 768)          3072      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 16, 16, 768)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 768)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 16, 16, 768)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 16, 16, 192)          147456    ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 16, 16, 192)          768       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 16, 16, 192)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 16, 16, 192)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 16, 16, 768)          147456    ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 16, 16, 768)          3072      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 16, 16, 768)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 16, 16, 768)          6912      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 16, 16, 768)          3072      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 16, 16, 768)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 768)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
# ...
#  block7g_dwconv2 (Depthwise  (None, 8, 8, 3840)           34560     ['block7g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7g_bn (BatchNormaliza  (None, 8, 8, 3840)           15360     ['block7g_dwconv2[0][0]']
#  tion)
#
#  block7g_activation (Activa  (None, 8, 8, 3840)           0         ['block7g_bn[0][0]']
#  tion)
#
#  block7g_se_squeeze (Global  (None, 3840)                 0         ['block7g_activation[0][0]']
#  AveragePooling2D)
#
#  block7g_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7g_se_squeeze[0][0]']
#  e)
#
#  block7g_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multipl  (None, 8, 8, 3840)           0         ['block7g_activation[0][0]',
#  y)                                                                  'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv  (None, 8, 8, 640)            2457600   ['block7g_se_excite[0][0]']
#  2D)
#
#  block7g_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7g_project_conv[0][0]']
#  ormalization)
#
#  block7g_drop (Dropout)      (None, 8, 8, 640)            0         ['block7g_project_bn[0][0]']
#
#  block7g_add (Add)           (None, 8, 8, 640)            0         ['block7g_drop[0][0]',
#                                                                      'block7f_add[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 1280)           819200    ['block7g_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 1280)           0         ['top_bn[0][0]']
#  )
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 1280)         0         ['top_activation[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 16, 16, 2624)         0         ['up_sampling2d[0][0]',
#                                                                      'block6a_expand_activation[0]
#                                                                     [0]']
#
#  conv2d (Conv2D)             (None, 16, 16, 80)           1889360   ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 80)           320       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 16, 16, 80)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 80)           57680     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 80)           320       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 16, 16, 80)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 80)           0         ['activation_1[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 464)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'block4a_expand_activation[0]
#                                                                     [0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)           267328    ['concatenate_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 64)           0         ['activation_3[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 320)          0         ['up_sampling2d_2[0][0]',
#  )                                                                   'block2g_expand_activation[0]
#                                                                     [0]']
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 48)           138288    ['concatenate_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 48)           192       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 48)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 48)           20784     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 48)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 48)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  up_sampling2d_3 (UpSamplin  (None, 128, 128, 48)         0         ['activation_5[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 80)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'block1d_project_activation[0
#                                                                     ][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 32)         23072     ['concatenate_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 128, 32)         128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 128, 32)         128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  up_sampling2d_4 (UpSamplin  (None, 256, 256, 32)         0         ['activation_7[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 35)         0         ['up_sampling2d_4[0][0]',
#  )                                                                   'input_image[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 16)         5056      ['concatenate_4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 256, 256, 16)         64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 16)         2320      ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 256, 256, 16)         64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 1)          17        ['activation_9[0][0]']
#
#  activation_10 (Activation)  (None, 256, 256, 1)          0         ['conv2d_10[0][0]']
#
# ==================================================================================================
# Total params: 120198849 (458.52 MB)
# Trainable params: 119685313 (456.56 MB)
# Non-trainable params: 513536 (1.96 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Metrics

# %%
smooth = 1e-15

def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# # Training

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH_SIZE)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH_SIZE)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [cdc, bahd]
model.compile(loss=cdc_loss, optimizer=opt, metrics=metrics)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x) // BATCH_SIZE
valid_steps = len(valid_x) // BATCH_SIZE

if len(train_x) % BATCH_SIZE != 0:
    train_steps += 1
if len(valid_x) % BATCH_SIZE != 0:
    valid_steps += 1
    
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 2024-02-06 21:10:42.547231: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 5929074288 exceeds 10% of free system memory.
# 2024-02-06 21:10:42.552440: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 5929074288 exceeds 10% of free system memory.
# 2024-02-06 21:10:50.983707: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1482268572 exceeds 10% of free system memory.
# 2024-02-06 21:11:10.360603: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1482268572 exceeds 10% of free system memory.
# 2024-02-06 21:11:30.517557: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8d3ea29200 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-02-06 21:11:30.518018: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2024-02-06 21:11:30.719169: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1707264691.058803   71839 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-02-06 21:11:31.064628: E external/local_xla/xla/stream_executor/stream_executor_internal.h:177] SetPriority unimplemented for this stream.

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH_SIZE)

test_steps = len(test_x) // BATCH_SIZE
if len(test_x) % BATCH_SIZE != 0:
    test_steps += 1
    
model.evaluate(test_dataset, steps=test_steps)

# %% [markdown]
# # Results

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)

    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
