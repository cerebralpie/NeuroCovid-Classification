# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import (
    Conv2D, Activation, BatchNormalization,
    UpSampling2D, Input, Concatenate
)
from tensorflow.keras.layers import Dropout, Conv2DTranspose, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K
#from src.metrics import (
#    cdc, cdc_loss, bahd
#)
# Out:
# 2024-02-19 17:41:59.644676: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-19 17:41:59.644742: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-19 17:41:59.646690: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-19 17:41:59.663918: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-19 17:42:01.536186: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.keras.backend.clear_session()

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Hyperparameters

# %%
IMAGE_SIZE = 256
EPOCHS = 30
BATCH_SIZE = 2
LR = 1e-4

PATH = "."

# %% [markdown]
# # Dataset

# %%
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))
    
    total_size = len(images)
    valid_size = int(total_size * split)
    test_size = int(total_size * split)
    
    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)
    
    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)
    
    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x / 255.0
    
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    
    return x

# %% [markdown]
# ## Building the tf.data pipeline

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        
        return x, y
    
    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    
    return x, y


def tf_dataset(x, y, batch=BATCH_SIZE):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    
    return dataset

# %%
# (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(PATH)
# 
# print("Training data: ", len(train_x))
# print("Validation data: ", len(valid_x))
# print("Testing data: ", len(test_x))

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    
    return x

# %% [markdown]
# # Model

# %%
#inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
#encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)

# %%
#encoder.summary()

# %%
inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
encoder2 = NASNetLarge(input_tensor=inputs, weights='imagenet', include_top=False)
# Out:
# 2024-02-19 17:42:04.489006: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.552391: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.552747: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.554564: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.554956: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.555225: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.610412: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.610774: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.611102: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-19 17:42:04.611309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA GeForce 920MX, pci bus id: 0000:01:00.0, compute capability: 5.0

# %%
encoder2.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 127, 127, 96)         2592      ['input_image[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 127, 127, 96)         384       ['stem_conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 127, 127, 96)         0         ['stem_bn1[0][0]']
#
#  reduction_conv_1_stem_1 (C  (None, 127, 127, 42)         4032      ['activation[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 127, 127, 42)         168       ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
#  activation_1 (Activation)   (None, 127, 127, 42)         0         ['reduction_bn_1_stem_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 127, 127, 96)         0         ['stem_bn1[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 131, 131, 42)         0         ['activation_1[0][0]']
#  tion_left1_stem_1 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 133, 133, 96)         0         ['activation_3[0][0]']
#  tion_right1_stem_1 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 64, 64, 42)           2814      ['separable_conv_1_pad_reducti
#  _left1_stem_1 (SeparableCo                                         on_left1_stem_1[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 64, 64, 42)           8736      ['separable_conv_1_pad_reducti
#  _right1_stem_1 (SeparableC                                         on_right1_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_1_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_1_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)   (None, 64, 64, 42)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 42)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_2_reduction  (None, 64, 64, 42)           2814      ['activation_2[0][0]']
#  _left1_stem_1 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 64, 64, 42)           3822      ['activation_4[0][0]']
#  _right1_stem_1 (SeparableC
#  onv2D)
#
#  activation_5 (Activation)   (None, 127, 127, 96)         0         ['stem_bn1[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_2_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_2_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 133, 133, 96)         0         ['activation_5[0][0]']
#  tion_right2_stem_1 (ZeroPa
#  dding2D)
#
#  activation_7 (Activation)   (None, 127, 127, 96)         0         ['stem_bn1[0][0]']
#
#  reduction_add_1_stem_1 (Ad  (None, 64, 64, 42)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_1[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_1_reduction  (None, 64, 64, 42)           8736      ['separable_conv_1_pad_reducti
#  _right2_stem_1 (SeparableC                                         on_right2_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 131, 131, 96)         0         ['activation_7[0][0]']
#  tion_right3_stem_1 (ZeroPa
#  dding2D)
#
#  activation_9 (Activation)   (None, 64, 64, 42)           0         ['reduction_add_1_stem_1[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_1_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 64, 64, 42)           6432      ['separable_conv_1_pad_reducti
#  _right3_stem_1 (SeparableC                                         on_right3_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 64, 64, 42)           2142      ['activation_9[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  activation_6 (Activation)   (None, 64, 64, 42)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_1_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_1_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_pad_1_stem_1 (Ze  (None, 129, 129, 42)         0         ['reduction_bn_1_stem_1[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 64, 64, 42)           3822      ['activation_6[0][0]']
#  _right2_stem_1 (SeparableC
#  onv2D)
#
#  activation_8 (Activation)   (None, 64, 64, 42)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  activation_10 (Activation)  (None, 64, 64, 42)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (Ma  (None, 64, 64, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_2_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 64, 64, 42)           2814      ['activation_8[0][0]']
#  _right3_stem_1 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 64, 64, 42)           2142      ['activation_10[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_stem_2 (Acti  (None, 127, 127, 96)         0         ['stem_bn1[0][0]']
#  vation)
#
#  reduction_add_2_stem_1 (Ad  (None, 64, 64, 42)           0         ['reduction_left2_stem_1[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Av  (None, 64, 64, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_2_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  reduction_left4_stem_1 (Av  (None, 64, 64, 42)           0         ['reduction_add_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 64, 64, 42)           168       ['separable_conv_2_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_right5_stem_1 (M  (None, 64, 64, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d (ZeroPaddin  (None, 128, 128, 96)         0         ['adjust_relu_1_stem_2[0][0]']
#  g2D)
#
#  reduction_add3_stem_1 (Add  (None, 64, 64, 42)           0         ['reduction_left3_stem_1[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  add (Add)                   (None, 64, 64, 42)           0         ['reduction_add_2_stem_1[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_1[0][0]
#                                                                     ']
#
#  reduction_add4_stem_1 (Add  (None, 64, 64, 42)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]',
#                                                                      'reduction_right5_stem_1[0][0
#                                                                     ]']
#
#  cropping2d (Cropping2D)     (None, 127, 127, 96)         0         ['zero_padding2d[0][0]']
#
#  reduction_concat_stem_1 (C  (None, 64, 64, 168)          0         ['reduction_add_2_stem_1[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_1[0][0]'
#                                                                     , 'add[0][0]',
#                                                                      'reduction_add4_stem_1[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_stem_2 (  (None, 64, 64, 96)           0         ['adjust_relu_1_stem_2[0][0]']
#  AveragePooling2D)
#
#  adjust_avg_pool_2_stem_2 (  (None, 64, 64, 96)           0         ['cropping2d[0][0]']
#  AveragePooling2D)
#
#  activation_11 (Activation)  (None, 64, 64, 168)          0         ['reduction_concat_stem_1[0][0
#                                                                     ]']
#
#  adjust_conv_1_stem_2 (Conv  (None, 64, 64, 42)           4032      ['adjust_avg_pool_1_stem_2[0][
#  2D)                                                                0]']
#
#  adjust_conv_2_stem_2 (Conv  (None, 64, 64, 42)           4032      ['adjust_avg_pool_2_stem_2[0][
#  2D)                                                                0]']
#
#  reduction_conv_1_stem_2 (C  (None, 64, 64, 84)           14112     ['activation_11[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)   (None, 64, 64, 84)           0         ['adjust_conv_1_stem_2[0][0]',
#                                                                      'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (Bat  (None, 64, 64, 84)           336       ['reduction_conv_1_stem_2[0][0
#  chNormalization)                                                   ]']
#
#  adjust_bn_stem_2 (BatchNor  (None, 64, 64, 84)           336       ['concatenate[0][0]']
#  malization)
#
#  activation_12 (Activation)  (None, 64, 64, 84)           0         ['reduction_bn_1_stem_2[0][0]'
#                                                                     ]
#
#  activation_14 (Activation)  (None, 64, 64, 84)           0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 67, 67, 84)           0         ['activation_12[0][0]']
#  tion_left1_stem_2 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 69, 69, 84)           0         ['activation_14[0][0]']
#  tion_right1_stem_2 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 84)           9156      ['separable_conv_1_pad_reducti
#  _left1_stem_2 (SeparableCo                                         on_left1_stem_2[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 84)           11172     ['separable_conv_1_pad_reducti
#  _right1_stem_2 (SeparableC                                         on_right1_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_1_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_1_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  activation_13 (Activation)  (None, 32, 32, 84)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_2[0][0]']
#
#  activation_15 (Activation)  (None, 32, 32, 84)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_2_reduction  (None, 32, 32, 84)           9156      ['activation_13[0][0]']
#  _left1_stem_2 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 32, 32, 84)           11172     ['activation_15[0][0]']
#  _right1_stem_2 (SeparableC
#  onv2D)
#
#  activation_16 (Activation)  (None, 64, 64, 84)           0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_2_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_2_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 69, 69, 84)           0         ['activation_16[0][0]']
#  tion_right2_stem_2 (ZeroPa
#  dding2D)
#
#  activation_18 (Activation)  (None, 64, 64, 84)           0         ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Ad  (None, 32, 32, 84)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_2[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_1_reduction  (None, 32, 32, 84)           11172     ['separable_conv_1_pad_reducti
#  _right2_stem_2 (SeparableC                                         on_right2_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 67, 67, 84)           0         ['activation_18[0][0]']
#  tion_right3_stem_2 (ZeroPa
#  dding2D)
#
#  activation_20 (Activation)  (None, 32, 32, 84)           0         ['reduction_add_1_stem_2[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_1_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 32, 32, 84)           9156      ['separable_conv_1_pad_reducti
#  _right3_stem_2 (SeparableC                                         on_right3_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 84)           7812      ['activation_20[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  activation_17 (Activation)  (None, 32, 32, 84)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_1_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_1_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_pad_1_stem_2 (Ze  (None, 65, 65, 84)           0         ['reduction_bn_1_stem_2[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 32, 32, 84)           11172     ['activation_17[0][0]']
#  _right2_stem_2 (SeparableC
#  onv2D)
#
#  activation_19 (Activation)  (None, 32, 32, 84)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  activation_21 (Activation)  (None, 32, 32, 84)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (Ma  (None, 32, 32, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_2_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 32, 32, 84)           9156      ['activation_19[0][0]']
#  _right3_stem_2 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 32, 32, 84)           7812      ['activation_21[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_0 (Activatio  (None, 64, 64, 168)          0         ['reduction_concat_stem_1[0][0
#  n)                                                                 ]']
#
#  reduction_add_2_stem_2 (Ad  (None, 32, 32, 84)           0         ['reduction_left2_stem_2[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Av  (None, 32, 32, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_2_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  reduction_left4_stem_2 (Av  (None, 32, 32, 84)           0         ['reduction_add_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 84)           336       ['separable_conv_2_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_right5_stem_2 (M  (None, 32, 32, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_1 (ZeroPadd  (None, 65, 65, 168)          0         ['adjust_relu_1_0[0][0]']
#  ing2D)
#
#  reduction_add3_stem_2 (Add  (None, 32, 32, 84)           0         ['reduction_left3_stem_2[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  add_1 (Add)                 (None, 32, 32, 84)           0         ['reduction_add_2_stem_2[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_2[0][0]
#                                                                     ']
#
#  reduction_add4_stem_2 (Add  (None, 32, 32, 84)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]',
#                                                                      'reduction_right5_stem_2[0][0
#                                                                     ]']
#
#  cropping2d_1 (Cropping2D)   (None, 64, 64, 168)          0         ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (C  (None, 32, 32, 336)          0         ['reduction_add_2_stem_2[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_2[0][0]'
#                                                                     , 'add_1[0][0]',
#                                                                      'reduction_add4_stem_2[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_0 (Avera  (None, 32, 32, 168)          0         ['adjust_relu_1_0[0][0]']
#  gePooling2D)
#
#  adjust_avg_pool_2_0 (Avera  (None, 32, 32, 168)          0         ['cropping2d_1[0][0]']
#  gePooling2D)
#
#  adjust_conv_1_0 (Conv2D)    (None, 32, 32, 84)           14112     ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)    (None, 32, 32, 84)           14112     ['adjust_avg_pool_2_0[0][0]']
#
#  activation_22 (Activation)  (None, 32, 32, 336)          0         ['reduction_concat_stem_2[0][0
#                                                                     ]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 168)          0         ['adjust_conv_1_0[0][0]',
#  )                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)    (None, 32, 32, 168)          56448     ['activation_22[0][0]']
#
#  adjust_bn_0 (BatchNormaliz  (None, 32, 32, 168)          672       ['concatenate_1[0][0]']
#  ation)
#
#  normal_bn_1_0 (BatchNormal  (None, 32, 32, 168)          672       ['normal_conv_1_0[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 32, 32, 168)          0         ['normal_bn_1_0[0][0]']
#
#  activation_25 (Activation)  (None, 32, 32, 168)          0         ['adjust_bn_0[0][0]']
#
#  activation_27 (Activation)  (None, 32, 32, 168)          0         ['adjust_bn_0[0][0]']
#
#  activation_29 (Activation)  (None, 32, 32, 168)          0         ['adjust_bn_0[0][0]']
#
#  activation_31 (Activation)  (None, 32, 32, 168)          0         ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_le  (None, 32, 32, 168)          32424     ['activation_23[0][0]']
#  ft1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 32, 32, 168)          29736     ['activation_25[0][0]']
#  ght1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 32, 32, 168)          32424     ['activation_27[0][0]']
#  ft2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 32, 32, 168)          29736     ['activation_29[0][0]']
#  ght2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 32, 32, 168)          29736     ['activation_31[0][0]']
#  ft5_0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 32, 32, 168)          672       ['separable_conv_1_normal_left
#  _left1_0 (BatchNormalizati                                         1_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 32, 32, 168)          672       ['separable_conv_1_normal_righ
#  _right1_0 (BatchNormalizat                                         t1_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 32, 32, 168)          672       ['separable_conv_1_normal_left
#  _left2_0 (BatchNormalizati                                         2_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 32, 32, 168)          672       ['separable_conv_1_normal_righ
#  _right2_0 (BatchNormalizat                                         t2_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 32, 32, 168)          672       ['separable_conv_1_normal_left
#  _left5_0 (BatchNormalizati                                         5_0[0][0]']
#  on)
#
#  activation_24 (Activation)  (None, 32, 32, 168)          0         ['separable_conv_1_bn_normal_l
#                                                                     eft1_0[0][0]']
#
#  activation_26 (Activation)  (None, 32, 32, 168)          0         ['separable_conv_1_bn_normal_r
#                                                                     ight1_0[0][0]']
#
#  activation_28 (Activation)  (None, 32, 32, 168)          0         ['separable_conv_1_bn_normal_l
#                                                                     eft2_0[0][0]']
#
#  activation_30 (Activation)  (None, 32, 32, 168)          0         ['separable_conv_1_bn_normal_r
#                                                                     ight2_0[0][0]']
#
#  activation_32 (Activation)  (None, 32, 32, 168)          0         ['separable_conv_1_bn_normal_l
#                                                                     eft5_0[0][0]']
# ...
#                                                                      'normal_add_5_17[0][0]']
#
#  activation_247 (Activation  (None, 8, 8, 4032)           0         ['normal_concat_16[0][0]']
#  )
#
#  activation_248 (Activation  (None, 8, 8, 4032)           0         ['normal_concat_17[0][0]']
#  )
#
#  adjust_conv_projection_18   (None, 8, 8, 672)            2709504   ['activation_247[0][0]']
#  (Conv2D)
#
#  normal_conv_1_18 (Conv2D)   (None, 8, 8, 672)            2709504   ['activation_248[0][0]']
#
#  adjust_bn_18 (BatchNormali  (None, 8, 8, 672)            2688      ['adjust_conv_projection_18[0]
#  zation)                                                            [0]']
#
#  normal_bn_1_18 (BatchNorma  (None, 8, 8, 672)            2688      ['normal_conv_1_18[0][0]']
#  lization)
#
#  activation_249 (Activation  (None, 8, 8, 672)            0         ['normal_bn_1_18[0][0]']
#  )
#
#  activation_251 (Activation  (None, 8, 8, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_253 (Activation  (None, 8, 8, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_255 (Activation  (None, 8, 8, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_257 (Activation  (None, 8, 8, 672)            0         ['normal_bn_1_18[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 8, 8, 672)            468384    ['activation_249[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 8, 8, 672)            457632    ['activation_251[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 8, 8, 672)            468384    ['activation_253[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 8, 8, 672)            457632    ['activation_255[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 8, 8, 672)            457632    ['activation_257[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_1_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_1_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_1_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_1_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_1_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  activation_250 (Activation  (None, 8, 8, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_18[0][0]']
#
#  activation_252 (Activation  (None, 8, 8, 672)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight1_18[0][0]']
#
#  activation_254 (Activation  (None, 8, 8, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft2_18[0][0]']
#
#  activation_256 (Activation  (None, 8, 8, 672)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight2_18[0][0]']
#
#  activation_258 (Activation  (None, 8, 8, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft5_18[0][0]']
#
#  separable_conv_2_normal_le  (None, 8, 8, 672)            468384    ['activation_250[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 8, 8, 672)            457632    ['activation_252[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 8, 8, 672)            468384    ['activation_254[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 8, 8, 672)            457632    ['activation_256[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 8, 8, 672)            457632    ['activation_258[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_2_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_2_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_2_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_2_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_2_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  normal_left3_18 (AveragePo  (None, 8, 8, 672)            0         ['normal_bn_1_18[0][0]']
#  oling2D)
#
#  normal_left4_18 (AveragePo  (None, 8, 8, 672)            0         ['adjust_bn_18[0][0]']
#  oling2D)
#
#  normal_right4_18 (AverageP  (None, 8, 8, 672)            0         ['adjust_bn_18[0][0]']
#  ooling2D)
#
#  separable_conv_2_bn_normal  (None, 8, 8, 672)            2688      ['separable_conv_2_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  normal_add_1_18 (Add)       (None, 8, 8, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft1_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight1_18[0][0]']
#
#  normal_add_2_18 (Add)       (None, 8, 8, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft2_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight2_18[0][0]']
#
#  normal_add_3_18 (Add)       (None, 8, 8, 672)            0         ['normal_left3_18[0][0]',
#                                                                      'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)       (None, 8, 8, 672)            0         ['normal_left4_18[0][0]',
#                                                                      'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)       (None, 8, 8, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft5_18[0][0]',
#                                                                      'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concaten  (None, 8, 8, 4032)           0         ['adjust_bn_18[0][0]',
#  ate)                                                                'normal_add_1_18[0][0]',
#                                                                      'normal_add_2_18[0][0]',
#                                                                      'normal_add_3_18[0][0]',
#                                                                      'normal_add_4_18[0][0]',
#                                                                      'normal_add_5_18[0][0]']
#
#  activation_259 (Activation  (None, 8, 8, 4032)           0         ['normal_concat_18[0][0]']
#  )
#
# ==================================================================================================
# Total params: 84916818 (323.93 MB)
# Trainable params: 84720150 (323.18 MB)
# Non-trainable params: 196668 (768.23 KB)
# __________________________________________________________________________________________________

# %%
x = encoder2.get_layer('activation_3').output
x = Conv2DTranspose(x.shape[3], (2, 2), strides=(1, 1), padding='valid')(x)
x.shape
# Out:
# TensorShape([None, 128, 128, 96])

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")

    encoder = NASNetLarge(input_tensor=inputs, weights="imagenet", include_top=False)
    # skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    skip_connection_names = ["input_image", "activation_3", "activation_14", "activation_97", "activation_180"]
    encoder_output = encoder.get_layer("activation_259").output
    #skip_connection_names = ["input_image", "re_lu", "re_lu_3", "re_lu_7"]
    #encoder_output = encoder.get_layer("re_lu_16").output

    f = [16, 32, 48, 64, 80]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])

        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)

    model = Model(inputs, x)
    return model

# %%
model = model()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model = model()
#       2 model.summary()
#
# Cell In[29], line 16, in model()
#      14 x_skip = encoder.get_layer(skip_connection_names[-i]).output
#      15 x = UpSampling2D((2, 2))(x)
# ---> 16 x = Concatenate()([x, x_skip])
#      18 x = Conv2D(f[-i], (3, 3), padding="same")(x)
#      19 x = BatchNormalization()(x)
#
# File ~/PycharmProjects/NeuroCovid-Classification/NeuroCovid/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/PycharmProjects/NeuroCovid-Classification/NeuroCovid/lib/python3.11/site-packages/keras/src/layers/merging/concatenate.py:131, in Concatenate.build(self, input_shape)
#     125 unique_dims = set(
#     126     shape[axis]
#     127     for shape in shape_set
#     128     if shape[axis] is not None
#     129 )
#     130 if len(unique_dims) > 1:
# --> 131     raise ValueError(err_msg)
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 128, 128, 48), (None, 127, 127, 96)]

# %% [markdown]
# # Metrics

# %%
smooth = 1e-15

def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# # Training

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH_SIZE)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH_SIZE)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [cdc, bahd]
model.compile(loss=cdc_loss, optimizer=opt, metrics=metrics)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x) // BATCH_SIZE
valid_steps = len(valid_x) // BATCH_SIZE

if len(train_x) % BATCH_SIZE != 0:
    train_steps += 1
if len(valid_x) % BATCH_SIZE != 0:
    valid_steps += 1
    
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH_SIZE)

test_steps = len(test_x) // BATCH_SIZE
if len(test_x) % BATCH_SIZE != 0:
    test_steps += 1
    
model.evaluate(test_dataset, steps=test_steps)

# %% [markdown]
# # Results

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)

    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
